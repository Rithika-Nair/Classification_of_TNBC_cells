# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
df = pd.read_csv('new_input.csv')
df
#len(df)
# Out:
#          geo_ID  1007_s_at   1053_at    117_at   1294_at   1316_at  1405_i_at  \
# 0    GSM1588970  10.411779  6.591003  5.903459  7.464439  3.428804   9.524660
# 1    GSM1588971  10.488352  6.746441  5.964176  7.202077  3.349296   9.419767
# 2    GSM1588972  10.845107  7.785105  7.073847  7.043459  5.267383  10.133473
# 3    GSM1588973  10.702966  7.680055  6.238866  6.479513  4.102789  10.080215
# 4    GSM1588974   9.098584  8.492950  7.898332  7.407747  3.387792   9.271527
# ..          ...        ...       ...       ...       ...       ...        ...
# 957  GSM1176949  10.750000  7.550000  7.080000  7.300000  5.800000   9.420000
# 958  GSM1176950  11.530000  7.430000  6.190000  7.370000  5.800000   8.820000
# 959  GSM1176951  10.420000  7.690000  6.430000  8.400000  5.260000  11.160000
# 960  GSM1176952  11.070000  8.250000  6.740000  7.780000  5.360000   7.590000
# 961  GSM1176953  11.520000  7.950000  6.050000  6.710000  5.350000   9.320000
#
#        1438_at   1487_at  1552256_a_at  ...  89476_r_at  90265_at  90610_at  \
# 0     7.279867  6.809069      9.304013  ...    7.866042  7.397357  8.183114
# 1     7.338068  6.812936      9.392534  ...    7.324577  7.250469  7.703048
# 2     1.990306  7.187364      8.291721  ...    7.472723  6.511484  7.695435
# 3     1.638085  7.097324      8.037302  ...    7.765743  7.031744  7.270343
# 4     1.747721  6.831582      8.624795  ...    6.958128  7.635051  7.649692
# ..         ...       ...           ...  ...         ...       ...       ...
# 957   6.670000  7.650000      8.420000  ...    7.120000  7.640000  8.310000
# 958   6.630000  7.520000      8.040000  ...    7.200000  7.390000  8.260000
# 959   7.520000  8.300000      9.500000  ...    7.150000  8.010000  8.830000
# 960   7.990000  8.000000      9.700000  ...    7.210000  8.030000  8.290000
# 961  10.950000  8.900000      9.330000  ...    7.920000  7.740000  8.210000
#
#      91617_at  91684_g_at  91703_at  91816_f_at  91826_at  91952_at      type
# 0    7.686229    7.984722  5.773304    2.419203  5.860008  4.740495      TNBC
# 1    7.398554    7.495566  5.765953    2.868395  6.111840  4.700452      TNBC
# 2    6.319967    6.551697  5.430892    4.220361  7.824272  4.285753  non-TNBC
# 3    6.364491    6.560303  5.091681    4.017962  7.888248  3.904448  non-TNBC
# 4    6.432153    7.451614  5.413343    7.336967  4.362245  5.025565      TNBC
# ..        ...         ...       ...         ...       ...       ...       ...
# 957  7.780000    7.350000  6.570000    8.110000  7.880000  5.850000  non-TNBC
# 958  7.800000    7.750000  6.730000    8.180000  7.360000  5.970000  non-TNBC
# 959  7.380000    8.040000  7.490000    6.710000  7.430000  6.850000  non-TNBC
# 960  7.270000    8.120000  7.070000    8.970000  9.040000  6.800000  non-TNBC
# 961  6.920000    8.230000  7.030000    6.740000  6.800000  6.290000  non-TNBC
#
# [962 rows x 29502 columns]

# %%
df = df.fillna(value=0)
df
print(df.isnull().values.any())
# Out:
# False

# %%
X = df.drop('type', axis=1)
X = X.drop('geo_ID', axis=1)
y = df['type']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

y_pred
# Out:
# array(['non-TNBC', 'TNBC', 'TNBC', 'TNBC', 'non-TNBC', 'non-TNBC',
#        'non-TNBC', 'non-TNBC', 'non-TNBC', 'TNBC', 'TNBC', 'non-TNBC',
#        'TNBC', 'non-TNBC', 'TNBC', 'non-TNBC', 'non-TNBC', 'non-TNBC',
#        'non-TNBC', 'non-TNBC', 'non-TNBC', 'TNBC', 'TNBC', 'TNBC',
#        'non-TNBC', 'non-TNBC', 'TNBC', 'non-TNBC', 'non-TNBC', 'TNBC',
#        'TNBC', 'non-TNBC', 'TNBC', 'TNBC', 'non-TNBC', 'TNBC', 'TNBC',
#        'non-TNBC', 'TNBC', 'non-TNBC', 'non-TNBC', 'non-TNBC', 'non-TNBC',
#        'TNBC', 'TNBC', 'non-TNBC', 'TNBC', 'non-TNBC', 'non-TNBC', 'TNBC',
#        'non-TNBC', 'non-TNBC', 'TNBC', 'TNBC', 'TNBC', 'non-TNBC',
#        'non-TNBC', 'non-TNBC', 'non-TNBC', 'non-TNBC', 'TNBC', 'non-TNBC',
#        'non-TNBC', 'non-TNBC', 'TNBC', 'non-TNBC', 'non-TNBC', 'TNBC',
#        'non-TNBC', 'TNBC', 'non-TNBC', 'TNBC', 'TNBC', 'TNBC', 'TNBC',
#        'TNBC', 'TNBC', 'TNBC', 'non-TNBC', 'TNBC', 'non-TNBC', 'TNBC',
#        'non-TNBC', 'TNBC', 'non-TNBC', 'non-TNBC', 'non-TNBC', 'non-TNBC',
#        'non-TNBC', 'non-TNBC', 'non-TNBC', 'TNBC', 'TNBC', 'non-TNBC',
#        'TNBC', 'TNBC', 'non-TNBC', 'non-TNBC', 'TNBC', 'non-TNBC',
#        'non-TNBC', 'non-TNBC', 'non-TNBC', 'non-TNBC', 'TNBC', 'TNBC',
#        'non-TNBC', 'TNBC', 'non-TNBC', 'non-TNBC', 'non-TNBC', 'non-TNBC',
#        'TNBC', 'non-TNBC', 'TNBC', 'non-TNBC', 'non-TNBC', 'non-TNBC',
#        'non-TNBC', 'non-TNBC', 'TNBC', 'non-TNBC', 'non-TNBC', 'TNBC',
#        'TNBC', 'non-TNBC', 'non-TNBC', 'TNBC', 'TNBC', 'non-TNBC', 'TNBC',
#        'non-TNBC', 'non-TNBC', 'TNBC', 'TNBC', 'TNBC', 'TNBC', 'TNBC',
#        'non-TNBC', 'non-TNBC', 'TNBC', 'TNBC', 'non-TNBC', 'TNBC',
#        'non-TNBC', 'non-TNBC', 'TNBC', 'non-TNBC', 'TNBC', 'non-TNBC',
#        'non-TNBC', 'non-TNBC', 'non-TNBC', 'non-TNBC', 'TNBC', 'non-TNBC',
#        'non-TNBC', 'non-TNBC', 'non-TNBC', 'TNBC', 'TNBC', 'non-TNBC',
#        'TNBC', 'TNBC', 'TNBC', 'TNBC', 'TNBC', 'non-TNBC', 'TNBC', 'TNBC',
#        'TNBC', 'non-TNBC', 'non-TNBC', 'non-TNBC', 'non-TNBC', 'non-TNBC',
#        'non-TNBC', 'TNBC', 'non-TNBC', 'TNBC', 'non-TNBC', 'TNBC',
#        'non-TNBC', 'non-TNBC', 'non-TNBC', 'non-TNBC', 'non-TNBC',
#        'non-TNBC', 'TNBC', 'TNBC', 'TNBC', 'non-TNBC', 'TNBC'],
#       dtype=object)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[ 73  10]
#  [ 10 100]]
#               precision    recall  f1-score   support
#
#         TNBC       0.88      0.88      0.88        83
#     non-TNBC       0.91      0.91      0.91       110
#
#     accuracy                           0.90       193
#    macro avg       0.89      0.89      0.89       193
# weighted avg       0.90      0.90      0.90       193

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8963730569948186
